# %%
# Nika's notebook

# Import statements
import numpy as np
import pandas as pd
from pathlib import Path
# %matplotlib inline

# %%
# read the uscities csv. this file will be used for the longitude and latitude, as well as the density stats.
longlatdensity_csv = Path("../Data/uscities.csv")
longlatdensity_df = pd.read_csv(longlatdensity_csv)


# question to the group. Do we want to keep zipcodes?
# Having multiple zipcodes to one longlat will not look great in mapbox/datashader

# %%
pd.set_option('display.max_rows', None)

checkuscitiesdf = longlatdensity_df.loc[(longlatdensity_df.state_id == "NY")]
checkuscitiesdf
# Out:
#                             city                 city_ascii state_id  \
# 0                       New York                   New York       NY
# 18                      Brooklyn                   Brooklyn       NY
# 19                        Queens                     Queens       NY
# 34                     Manhattan                  Manhattan       NY
# 39                         Bronx                      Bronx       NY
# 52                       Buffalo                    Buffalo       NY
# 64                     Rochester                  Rochester       NY
# 75                        Albany                     Albany       NY
# 91                 Staten Island              Staten Island       NY
# 108                     Syracuse                   Syracuse       NY
# 112                 Poughkeepsie               Poughkeepsie       NY
# 223                      Yonkers                    Yonkers       NY
# 300                   Binghamton                 Binghamton       NY
# ...
