# %%
# Import library
import pandas as pd
from pathlib import Path

# %%
# Read in CSV file
csv_path = Path("../Data/house_prices_msa.csv")
house_price_raw = pd.read_csv(csv_path)
# index_col="RegionName"
# house_price_raw.drop(["RegionType"], axis = 1, inplace = True) 
# split the RegionName into City and State columns
house_price_raw[['City','State']] = house_price_raw.RegionName.str.split(",",expand=True)
# Reorder the state and city col to the first two col
city_col_name="City"
state_col_name="State"
region_col_name="RegionName"
first_col = house_price_raw.pop(city_col_name)
second_col = house_price_raw.pop(state_col_name)
third_col = house_price_raw.pop(region_col_name)
house_price_raw.insert(0, city_col_name, first_col)
house_price_raw.insert(1, state_col_name, second_col)
house_price_raw.insert(2, region_col_name, third_col)
# Set index as RegionName
house_price_raw_indexed = house_price_raw.set_index("City")
house_price_raw_indexed.drop(["RegionType","StateName"], axis = 1, inplace = True) 

house_price_raw_indexed.head(1000)
# Out:
#                                State                          RegionName  \
# City
# United States                   None                       United States
# New York                          NY                        New York, NY
# Los Angeles-Long Beach-Anaheim    CA  Los Angeles-Long Beach-Anaheim, CA
# Chicago                           IL                         Chicago, IL
# Dallas-Fort Worth                 TX               Dallas-Fort Worth, TX
# ...                              ...                                 ...
# Lamesa                            TX                          Lamesa, TX
# Craig                             CO                           Craig, CO
# Pecos                             TX                           Pecos, TX
# Vernon                            TX                          Vernon, TX
# Ketchikan                         AK                       Ketchikan, AK
#
#                                 RegionID  SizeRank  1/31/1996  2/29/1996  \
# City
# United States                     102001         0   107630.0   107657.0
# New York                          394913         1   187842.0   187403.0
# Los Angeles-Long Beach-Anaheim    753899         2   183929.0   184185.0
# Chicago                           394463         3   164647.0   164345.0
# Dallas-Fort Worth                 394514         4   114406.0   114471.0
# ...                                  ...       ...        ...        ...
# Lamesa                            394767       929        NaN        NaN
# Craig                             753874       930    60501.0    60725.0
# Pecos                             394968       931        NaN        NaN
# Vernon                            395188       932        NaN        NaN
# Ketchikan                         394743       933        NaN        NaN
#
#                                 3/31/1996  4/30/1996  5/31/1996  6/30/1996  \
# City
# United States                    107707.0   107834.0   107977.0   108147.0
# New York                         187125.0   186592.0   186274.0   185984.0
# Los Angeles-Long Beach-Anaheim   184205.0   184312.0   184286.0   184313.0
# Chicago                          163946.0   163493.0   162886.0   162557.0
# Dallas-Fort Worth                114634.0   114962.0   115314.0   115568.0
# ...                                   ...        ...        ...        ...
# Lamesa                                NaN        NaN        NaN        NaN
# Craig                             60961.0    61420.0    61747.0    62035.0
# Pecos                                 NaN        NaN        NaN        NaN
# Vernon                                NaN        NaN        NaN        NaN
# Ketchikan                             NaN        NaN        NaN        NaN
#
#                                 ...  12/31/2019  1/31/2020  2/29/2020  \
# City                            ...
# United States                   ...      247737     248625     249639
# New York                        ...      479999     480758     481745
# Los Angeles-Long Beach-Anaheim  ...      671796     675183     680320
# Chicago                         ...      245373     245631     246017
# Dallas-Fort Worth               ...      260294     260750     261428
# ...                             ...         ...        ...        ...
# Lamesa                          ...       75408      75568      75681
# Craig                           ...      187489     187062     186934
# Pecos                           ...      124046     125836     127175
# Vernon                          ...       69702      69630      69495
# Ketchikan                       ...      311672     312028     312133
#
#                                 3/31/2020  4/30/2020  5/31/2020  6/30/2020  \
# City
# United States                      250802     252042     253216     254423
# New York                           482804     484104     485517     487279
# Los Angeles-Long Beach-Anaheim     685503     689705     691229     692332
# Chicago                            246628     247155     247719     248421
# Dallas-Fort Worth                  262440     263584     264699     265992
# ...                                   ...        ...        ...        ...
# Lamesa                              75786      75968      76213      76503
# Craig                              186942     187037     187109     187262
# Pecos                              128373     128879     129605     130574
# Vernon                              69361      69277      69276      69229
# Ketchikan                          312265     312191     312216     312121
#
#                                 7/31/2020  8/31/2020  9/30/2020
# City
# United States                      255872     257736     259906
# New York                           489670     492875     497090
# Los Angeles-Long Beach-Anaheim     696613     703740     711361
# Chicago                            249650     251298     253512
# Dallas-Fort Worth                  267485     269183     270907
# ...                                   ...        ...        ...
# Lamesa                              76738      76975      77216
# Craig                              187332     187393     187430
# Pecos                              131262     131311     130703
# Vernon                              69236      69248      69306
# Ketchikan                          312147     312419     312663
#
# [914 rows x 301 columns]

# %%
# Clean and filter columns
house_price_df = house_price_raw_indexed.transpose() 
house_price_df
# house_price_df.set_index("RegionName")
# Out:
# City        United States      New York      Los Angeles-Long Beach-Anaheim  \
# State                None            NY                                  CA
# RegionName  United States  New York, NY  Los Angeles-Long Beach-Anaheim, CA
# RegionID           102001        394913                              753899
# SizeRank                0             1                                   2
# 1/31/1996          107630        187842                              183929
# ...                   ...           ...                                 ...
# 5/31/2020          253216        485517                              691229
# 6/30/2020          254423        487279                              692332
# 7/31/2020          255872        489670                              696613
# 8/31/2020          257736        492875                              703740
# 9/30/2020          259906        497090                              711361
#
# City            Chicago      Dallas-Fort Worth      Philadelphia      Houston  \
# State                IL                     TX                PA           TX
# RegionName  Chicago, IL  Dallas-Fort Worth, TX  Philadelphia, PA  Houston, TX
# RegionID         394463                 394514            394974       394692
# SizeRank              3                      4                 5            6
# 1/31/1996        164647                 114406            121233       110773
# ...                 ...                    ...               ...          ...
# 5/31/2020        247719                 264699            256799       224420
# 6/30/2020        248421                 265992            258666       225165
# 7/31/2020        249650                 267485            260637       226007
# 8/31/2020        251298                 269183            263126       227049
# 9/30/2020        253512                 270907            265912       228576
#
# City            Washington      Miami-Fort Lauderdale      Atlanta  ...  \
# State                   DC                         FL           GA  ...
# RegionName  Washington, DC  Miami-Fort Lauderdale, FL  Atlanta, GA  ...
# RegionID            395209                     394856       394347  ...
# SizeRank                 7                          8            9  ...
# 1/31/1996           178034                     109403       120291  ...
# ...                    ...                        ...          ...  ...
# 5/31/2020           441727                     302132       245768  ...
# 6/30/2020           444179                     303396       247242  ...
# 7/31/2020           447399                     304694       248841  ...
# 8/31/2020           451030                     306533       250642  ...
# 9/30/2020           455038                     308911       252586  ...
#
# City            Winnemucca      Sweetwater      Andrews      Zapata  \
# State                   NV              TX           TX          TX
# RegionName  Winnemucca, NV  Sweetwater, TX  Andrews, TX  Zapata, TX
# RegionID            753927          395142       394330      753929
# SizeRank               924             925          926         927
# 1/31/1996              NaN             NaN          NaN         NaN
# ...                    ...             ...          ...         ...
# 5/31/2020           226697           79991       170737       91481
# 6/30/2020           227020           80081       171393       91978
# 7/31/2020           227333           80159       172116       92335
# 8/31/2020           227223           80068       172764       92363
# 9/30/2020           226533           79985       173153       92602
#
# City            Vermillion      Lamesa      Craig      Pecos      Vernon  \
# State                   SD          TX         CO         TX          TX
# RegionName  Vermillion, SD  Lamesa, TX  Craig, CO  Pecos, TX  Vernon, TX
# RegionID            395186      394767     753874     394968      395188
# SizeRank               928         929        930        931         932
# 1/31/1996              NaN         NaN      60501        NaN         NaN
# ...                    ...         ...        ...        ...         ...
# 5/31/2020           179138       76213     187109     129605       69276
# 6/30/2020           179052       76503     187262     130574       69229
# 7/31/2020           178945       76738     187332     131262       69236
# 8/31/2020           179167       76975     187393     131311       69248
# 9/30/2020           179547       77216     187430     130703       69306
#
# City            Ketchikan
# State                  AK
# RegionName  Ketchikan, AK
# RegionID           394743
# SizeRank              933
# 1/31/1996             NaN
# ...                   ...
# 5/31/2020          312216
# 6/30/2020          312121
# 7/31/2020          312147
# 8/31/2020          312419
# 9/30/2020          312663
#
# [301 rows x 914 columns]

# %%
# Import second file
# Read in CSV file
csv_path_2 = Path("../Data/rental_prices_msa.csv")
rental_price_raw = pd.read_csv(csv_path_2)

# %%
# split the RegionName into City and State columns
rental_price_raw[['City','State']] = rental_price_raw.RegionName.str.split(",",expand=True)
# Reorder the state and city col to the first two col
city_col_name="City"
state_col_name="State"
region_col_name="RegionName"
first_col = rental_price_raw.pop(city_col_name)
second_col = rental_price_raw.pop(state_col_name)
third_col = rental_price_raw.pop(region_col_name)
rental_price_raw.insert(0, city_col_name, first_col)
rental_price_raw.insert(1, state_col_name, second_col)
rental_price_raw.insert(2, region_col_name, third_col)
# Set index as City
rental_price_raw_indexed = rental_price_raw.set_index("City")
rental_price_raw_indexed.sample(5)
# Out:
#                               State                         RegionName  \
# City
# Madison                          WI                        Madison, WI
# North Port-Sarasota-Bradenton    FL  North Port-Sarasota-Bradenton, FL
# Port St. Lucie                   FL                 Port St. Lucie, FL
# Colorado Springs                 CO               Colorado Springs, CO
# Ogden                            UT                          Ogden, UT
#
#                                RegionID  SizeRank  2014-01  2014-02  2014-03  \
# City
# Madison                          394816        87   1117.0   1117.0   1118.0
# North Port-Sarasota-Bradenton    753906        75   1359.0   1366.0   1373.0
# Port St. Lucie                   394995       119   1157.0   1165.0   1173.0
# Colorado Springs                 394484        80   1104.0   1110.0   1115.0
# Ogden                            394931        89    905.0    913.0    921.0
#
#                                2014-04  2014-05  2014-06  ...  2019-12  \
# City                                                      ...
# Madison                           1118     1118     1119  ...     1286
# North Port-Sarasota-Bradenton     1379     1386     1393  ...     1706
# Port St. Lucie                    1181     1189     1196  ...     1640
# Colorado Springs                  1121     1126     1132  ...     1544
# Ogden                              929      937      944  ...     1295
#
#                                2020-01  2020-02  2020-03  2020-04  2020-05  \
# City
# Madison                           1289     1291     1294     1296     1298
# North Port-Sarasota-Bradenton     1711     1715     1720     1725     1729
# Port St. Lucie                    1648     1656     1664     1671     1679
# Colorado Springs                  1550     1556     1563     1569     1575
# Ogden                             1300     1304     1309     1314     1318
#
#                                2020-06  2020-07  2020-08  2020-09
# City
# Madison                           1301     1303     1306     1308
# North Port-Sarasota-Bradenton     1734     1739     1744     1748
# Port St. Lucie                    1687     1695     1702     1710
# Colorado Springs                  1582     1588     1594     1600
# Ogden                             1323     1327     1332     1336
#
# [5 rows x 85 columns]

# %%
# Transpose columns
rental_price_df = rental_price_raw_indexed.transpose() 
rental_price_df
# Out:
# City        United States      New York      Los Angeles-Long Beach-Anaheim  \
# State                None            NY                                  CA
# RegionName  United States  New York, NY  Los Angeles-Long Beach-Anaheim, CA
# RegionID           102001        394913                              753899
# SizeRank                0             1                                   2
# 2014-01              1354          2296                                1857
# ...                   ...           ...                                 ...
# 2020-05              1707          2662                                2546
# 2020-06              1709          2653                                2546
# 2020-07              1710          2644                                2546
# 2020-08              1711          2635                                2545
# 2020-09              1712          2625                                2545
#
# City            Chicago      Dallas-Fort Worth      Philadelphia      Houston  \
# State                IL                     TX                PA           TX
# RegionName  Chicago, IL  Dallas-Fort Worth, TX  Philadelphia, PA  Houston, TX
# RegionID         394463                 394514            394974       394692
# SizeRank              3                      4                 5            6
# 2014-01            1527                   1222              1364         1272
# ...                 ...                    ...               ...          ...
# 2020-05            1775                   1567              1608         1485
# 2020-06            1774                   1568              1610         1485
# 2020-07            1772                   1570              1612         1484
# 2020-08            1771                   1571              1614         1484
# 2020-09            1770                   1572              1615         1483
#
# City            Washington      Miami-Fort Lauderdale      Atlanta  ...  \
# State                   DC                         FL           GA  ...
# RegionName  Washington, DC  Miami-Fort Lauderdale, FL  Atlanta, GA  ...
# RegionID            395209                     394856       394347  ...
# SizeRank                 7                          8            9  ...
# 2014-01               1893                       1571         1139  ...
# ...                    ...                        ...          ...  ...
# 2020-05               2117                       1936         1568  ...
# 2020-06               2115                       1938         1572  ...
# 2020-07               2113                       1940         1576  ...
# 2020-08               2111                       1942         1580  ...
# 2020-09               2108                       1944         1584  ...
#
# City            Melbourne      Chattanooga      Spokane      Provo  \
# State                  FL               TN           WA         UT
# RegionName  Melbourne, FL  Chattanooga, TN  Spokane, WA  Provo, UT
# RegionID           394957           394460       395113     395006
# SizeRank               97               98           99        100
# 2014-01               986              914          857        991
# ...                   ...              ...          ...        ...
# 2020-05              1486             1224         1203       1326
# 2020-06              1492             1229         1210       1328
# 2020-07              1498             1234         1216       1330
# 2020-08              1504             1239         1223       1332
# 2020-09              1510             1244         1230       1335
#
# City            Durham      Port St. Lucie      Fort Collins      Boulder  \
# State               NC                  FL                CO           CO
# RegionName  Durham, NC  Port St. Lucie, FL  Fort Collins, CO  Boulder, CO
# RegionID        394549              394995            394602       394405
# SizeRank           104                 119               159          162
# 2014-01           1173                1157              1239         1522
# ...                ...                 ...               ...          ...
# 2020-05           1434                1679              1649         1997
# 2020-06           1434                1687              1651         1998
# 2020-07           1434                1695              1653         1998
# 2020-08           1435                1702              1656         1999
# 2020-09           1435                1710              1658         2000
#
# City            Greeley      Gainesville
# State                CO               GA
# RegionName  Greeley, CO  Gainesville, GA
# RegionID         394645           394623
# SizeRank            177              229
# 2014-01            1252              978
# ...                 ...              ...
# 2020-05            1693             1413
# 2020-06            1695             1417
# 2020-07            1698             1420
# 2020-08            1700             1423
# 2020-09            1703             1427
#
# [85 rows x 106 columns]
